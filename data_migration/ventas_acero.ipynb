# %% [markdown]
# # Ventas acero 2023 - 2024

# %%
import pandas as pd
from typing import List

path_acero = "data/ventas_acero.xlsx"

# %%
# FUNCTIONS
def get_sheet_names(file_path: str) -> List[str]:
    """
    Get the names of all sheets in an Excel file.

    Args:
    file_path (str): The path to the Excel file from which the sheet names are to be retrieved.

    Returns:
    List[str]: A list of strings, where each string is the name of a sheet in the Excel file.

    Functionality:
    - Reads an Excel file using pandas.
    - Retrieves the names of all sheets in the Excel file.
    """
    # Read the excel file using pandas
    xls = pd.ExcelFile(file_path)
    
    # Get the names of all the sheets in the excel file
    sheet_names = xls.sheet_names
    
    # Return the list of sheet names
    return sheet_names

# %%
# Guardar nombres de cada hoja de Excel en el objeto sheet_names
sheet_names = get_sheet_names(path_acero)
print("Sheet names:")
print(sheet_names)
# Out:
# Sheet names:
# ['aretes_acero', 'aretes_acero_2', 'anillos_acero', 'anillos_acero_2', 'cadenas_acero', 'cadenas_acero_2', 'collar_acero', 'collar_acero_2', 'set_acero', 'set_acero_2', 'pulseras_acero', 'pulseras_acero_2', 'dijes_acero', 'dijes_acero_2', 'accesorios_acero', 'varios_acero', 'ssv_acero']

# %%
# 3. Use a for loop to read spreadsheets in sheet_names and append them in a list
# VALIDATION: Algunas columnas en el archivo original tenían mal el año. Por ejemplo diciembre de 2024
# se necesito fix manual en el archivo original 

list_of_df = []
for s in sheet_names:
    print(f"\nSheet Name: {s}")
    # Read sheet and add new column with sheet name
    df = pd.read_excel(path_acero, sheet_name=s)
    df["source"] = s
    
    # Append and print info
    list_of_df.append(df)
    print(f"Shape: {df.shape}")
    for n in df.columns :
        print(n)
# Out:
# Sheet Name: aretes_acero
# Shape: (380, 322)
# COD
# NUM
# 2023/03/15
# 2023/03/16
# 2023/03/17
# 2023/03/18
# 2023/03/20
# 2023/03/21
# 2023/03/22
# 2023/03/23
# 2023/03/24
# 2023/03/25
# 2023/03/28
# 2023/03/31
# 2023/04/01
# 2023/04/03
# 2023/04/04
# 2023/04/05
# 2023/04/06
# 2023/04/08
# 2023/04/10
# 2023/04/11
# 2023/04/12
# 2023/04/13
# 2023/04/14
# 2023/04/15
# 2023/04/18
# 2023/04/19
# 2023/04/20
# 2023/04/22
# 2023/04/24
# 2023/04/25
# 2023/04/26
# 2023/04/27
# 2023/04/29
# 2023/05/01
# 2023/05/02
# 2023/05/03
# 2023/05/04
# 2023/05/05
# 2023/05/06
# 2023/05/07
# 2023/05/09
# 2023/05/11
# 2023/05/12
# 2023/05/13
# 2023/05/15
# 2023/05/16
# 2023/05/17
# 2023/05/18
# 2023/05/20
# 2023/05/23
# 2023/05/25
# 2023/05/26
# 2023/05/27
# 2023/05/29
# 2023/05/30
# 2023/05/31
# 2023/06/02
# 2023/06/05
# 2023/06/08
# 2023/06/09
# 2023/06/10
# 2023/06/13
# 2023/06/16
# 2023/06/17
# 2023/06/19
# 2023/06/21
# 2023/06/22
# 2023/06/23
# 2023/06/24
# 2023/06/27
# 2023/06/29
# 2023/06/30
# 2023/04/20
# 2023/05/03
# 2023/05/05
# 2023/05/22
# 2023/05/23
# 2023/05/30
# 2023/06/07
# 2023/06/21
# 2023/07/08
# 2023/07/10
# 2023/08/15
# 2023/08/18
# 2023/09/14
# 2023/10/06
# 2023/10/10
# 2023/10/13
# 2023/10/23
# 2023/11/04
# 2023/11/06
# 2023/11/17
# 2023/11/26
# 2023/11/30
# 2023/12/03
# 2023/12/13
# 2023/12/16
# 2023/12/20
# 2023/12/22
# 2023/12/30
# 2024/01/13
# 2024/01/15
# 2024/01/23
# 2024/01/26
# 2024/02/15
# 2024/02/20
# 2024/03/02
# 2024/03/28
# 2024/04/17
# 2024/04/21
# 2024/04/26
# 2024/04/30
# 2024/05/03
# 2024/05/11
# 2024/05/17
# 2024/05/19
# 2024/05/20
# 2024/05/22
# 2024/06/01
# 2024/06/13
# 2024/06/25
# 2024/07/03
# 2024/07/12
# 2024/07/15
# 2024/07/17
# source
#
# Sheet Name: varios_acero
# Shape: (1, 35)
# COD
# NUM
# 2023/04/01
# 2023/04/19
# 2023/05/07
# 2023/05/12
# 2023/06/01
# 2023/06/10
# 2023/08/01
# 2023/08/29
# 2023/09/09
# 2023/09/15
# 2023/10/10
# 2023/10/13
# 2023/10/21
# 2023/10/25
# 2023/11/02
# 2023/11/03
# 2023/11/12
# 2023/11/18
# 2023/11/22
# 2023/11/25
# 2023/12/02
# 2024/01/13
# 2024/02/29
# 2024/03/21
# 2024/04/09
# 2024/04/19
# 2024/04/21
# 2024/04/26
# 2024/05/24
# 2024/07/05
# 2024/07/13
# 2024/07/14
# source
#
# Sheet Name: ssv_acero
# Shape: (10, 4)
# COD
# NUM
# 2023/07/13
# source

# %% [markdown]
# # Data Cleaning

# %%
# A. Creamos dataframe all concatenando todos los df de la lista list_of_df
# B. Convertimos los nombres de las columnas a str filtrando los 10 primeros caracteres
#    esto permite uniformizar los nombres de columnas repetidas en el archivo original

all = pd.concat(list_of_df)
print(f"Sheet Name: all")
print(f"Shape: {all.shape}")
all.columns= [str(c)[:10] for c in all.columns]
# Out:
# Sheet Name: all
# Shape: (1080, 419)

# %%
# C. Verificar tipos de datos de cada columna
# Las columnas de fechas deben ser float ya que contienen numeros entero y valores perdidos
for columna,tipo in zip(all.columns, all.dtypes):
    print(f'La columna {columna} es de tipo {tipo}')
# Out:
# La columna COD es de tipo object
# La columna NUM es de tipo float64
# La columna 2023/03/15 es de tipo float64
# La columna 2023/03/16 es de tipo float64
# La columna 2023/03/17 es de tipo float64
# La columna 2023/03/18 es de tipo float64
# La columna 2023/03/20 es de tipo float64
# La columna 2023/03/21 es de tipo float64
# La columna 2023/03/22 es de tipo float64
# La columna 2023/03/23 es de tipo float64
# La columna 2023/03/24 es de tipo float64
# La columna 2023/03/25 es de tipo float64
# La columna 2023/03/28 es de tipo float64
# La columna 2023/03/31 es de tipo float64
# La columna 2023/04/01 es de tipo float64
# La columna 2023/04/03 es de tipo float64
# La columna 2023/04/04 es de tipo float64
# La columna 2023/04/05 es de tipo float64
# La columna 2023/04/06 es de tipo float64
# La columna 2023/04/08 es de tipo float64
# La columna 2023/04/10 es de tipo float64
# La columna 2023/04/11 es de tipo float64
# La columna 2023/04/12 es de tipo float64
# La columna 2023/04/13 es de tipo float64
# La columna 2023/04/14 es de tipo float64
# La columna 2023/04/15 es de tipo float64
# La columna 2023/04/18 es de tipo float64
# La columna 2023/04/19 es de tipo float64
# La columna 2023/04/20 es de tipo float64
# La columna 2023/04/22 es de tipo float64
# La columna 2023/04/24 es de tipo float64
# La columna 2023/04/25 es de tipo float64
# La columna 2023/04/26 es de tipo float64
# La columna 2023/04/27 es de tipo float64
# La columna 2023/04/29 es de tipo float64
# La columna 2023/05/01 es de tipo float64
# La columna 2023/05/02 es de tipo float64
# La columna 2023/05/03 es de tipo float64
# La columna 2023/05/04 es de tipo float64
# La columna 2023/05/05 es de tipo float64
# La columna 2023/05/06 es de tipo float64
# La columna 2023/05/07 es de tipo float64
# La columna 2023/05/09 es de tipo float64
# La columna 2023/05/11 es de tipo float64
# La columna 2023/05/12 es de tipo float64
# La columna 2023/05/13 es de tipo float64
# La columna 2023/05/15 es de tipo float64
# La columna 2023/05/16 es de tipo float64
# La columna 2023/05/17 es de tipo float64
# La columna 2023/05/18 es de tipo float64
# La columna 2023/05/20 es de tipo float64
# La columna 2023/05/23 es de tipo float64
# La columna 2023/05/25 es de tipo float64
# La columna 2023/05/26 es de tipo float64
# La columna 2023/05/27 es de tipo float64
# La columna 2023/05/29 es de tipo float64
# La columna 2023/05/30 es de tipo float64
# La columna 2023/05/31 es de tipo float64
# La columna 2023/06/02 es de tipo float64
# La columna 2023/06/05 es de tipo float64
# La columna 2023/06/08 es de tipo float64
# La columna 2023/06/09 es de tipo float64
# La columna 2023/06/10 es de tipo float64
# La columna 2023/06/13 es de tipo float64
# La columna 2023/06/16 es de tipo float64
# La columna 2023/06/17 es de tipo float64
# La columna 2023/06/19 es de tipo float64
# La columna 2023/06/21 es de tipo float64
# La columna 2023/06/22 es de tipo float64
# La columna 2023/06/23 es de tipo float64
# La columna 2023/06/24 es de tipo float64
# La columna 2023/06/27 es de tipo float64
# La columna 2023/06/29 es de tipo float64
# La columna 2023/06/30 es de tipo float64
# La columna 2023/07/03 es de tipo float64
# La columna 2023/07/05 es de tipo float64
# La columna 2023/07/06 es de tipo float64
# La columna 2023/07/07 es de tipo float64
# La columna 2023/07/08 es de tipo float64
# La columna 2023/07/10 es de tipo float64
# La columna 2023/07/12 es de tipo float64
# La columna 2023/07/14 es de tipo float64
# La columna 2023/07/15 es de tipo float64
# La columna 2023/07/17 es de tipo float64
# La columna 2023/07/18 es de tipo float64
# La columna 2023/07/19 es de tipo float64
# La columna 2023/07/20 es de tipo float64
# La columna 2023/07/21 es de tipo float64
# La columna 2023/07/25 es de tipo float64
# La columna 2023/07/31 es de tipo float64
# La columna 2023/08/02 es de tipo float64
# La columna 2023/08/03 es de tipo float64
# La columna 2023/08/04 es de tipo float64
# La columna 2023/08/05 es de tipo float64
# La columna 2023/08/07 es de tipo float64
# La columna 2023/08/08 es de tipo float64
# La columna 2023/08/11 es de tipo float64
# La columna 2023/08/16 es de tipo float64
# La columna 2023/08/17 es de tipo float64
# La columna 2023/08/18 es de tipo float64
# La columna 2023/08/19 es de tipo float64
# La columna 2023/08/21 es de tipo float64
# La columna 2023/08/23 es de tipo float64
# La columna 2023/08/25 es de tipo float64
# La columna 2023/08/26 es de tipo float64
# La columna 2023/08/31 es de tipo float64
# La columna 2023/09/01 es de tipo float64
# La columna 2023/09/02 es de tipo float64
# La columna 2023/09/04 es de tipo float64
# La columna 2023/09/06 es de tipo float64
# La columna 2023/09/07 es de tipo float64
# La columna 2023/09/08 es de tipo float64
# La columna 2023/09/09 es de tipo float64
# La columna 2023/09/11 es de tipo float64
# La columna 2023/09/12 es de tipo float64
# La columna 2023/09/13 es de tipo float64
# La columna 2023/09/14 es de tipo float64
# La columna 2023/09/15 es de tipo float64
# La columna 2023/09/18 es de tipo float64
# La columna 2023/09/19 es de tipo float64
# La columna 2023/09/20 es de tipo float64
# La columna 2023/09/21 es de tipo float64
# La columna 2023/09/22 es de tipo float64
# La columna 2023/09/25 es de tipo float64
# La columna 2023/09/27 es de tipo float64
# La columna 2023/09/29 es de tipo float64
# La columna 2023/10/05 es de tipo float64
# La columna 2023/10/06 es de tipo float64
# La columna 2023/10/09 es de tipo float64
# La columna 2023/10/10 es de tipo float64
# La columna 2023/10/11 es de tipo float64
# La columna 2023/10/12 es de tipo float64
# La columna 2023/10/13 es de tipo float64
# La columna 2023/10/14 es de tipo float64
# La columna 2023/10/18 es de tipo float64
# La columna 2023/10/21 es de tipo float64
# La columna 2023/10/23 es de tipo float64
# La columna 2023/10/24 es de tipo float64
# La columna 2023/10/26 es de tipo float64
# La columna 2023/10/27 es de tipo float64
# La columna 2023/10/28 es de tipo float64
# La columna 2023/10/30 es de tipo float64
# La columna 2023/10/31 es de tipo float64
# La columna 2023/11/01 es de tipo float64
# La columna 2023/11/02 es de tipo float64
# La columna 2023/11/03 es de tipo float64
# La columna 2023/11/05 es de tipo float64
# La columna 2023/11/06 es de tipo float64
# La columna 2023/11/08 es de tipo float64
# La columna 2023/11/09 es de tipo float64
# La columna 2023/11/10 es de tipo float64
# La columna 2023/11/11 es de tipo float64
# La columna 2023/11/15 es de tipo float64
# La columna 2023/11/16 es de tipo float64
# La columna 2023/11/17 es de tipo float64
# La columna 2023/11/18 es de tipo float64
# La columna 2023/11/19 es de tipo float64
# La columna 2023/11/22 es de tipo float64
# La columna 2023/11/23 es de tipo float64
# La columna 2023/11/24 es de tipo float64
# La columna 2023/11/25 es de tipo float64
# La columna 2023/11/27 es de tipo float64
# La columna 2023/11/28 es de tipo float64
# La columna 2023/11/29 es de tipo float64
# La columna 2023/11/30 es de tipo float64
# La columna 2023/12/02 es de tipo float64
# La columna 2023/12/04 es de tipo float64
# La columna 2023/12/05 es de tipo float64
# La columna 2023/12/06 es de tipo float64
# La columna 2023/12/08 es de tipo float64
# La columna 2023/12/09 es de tipo float64
# La columna 2023/12/10 es de tipo float64
# La columna 2023/12/11 es de tipo float64
# La columna 2023/12/12 es de tipo float64
# La columna 2023/12/13 es de tipo float64
# La columna 2023/12/14 es de tipo float64
# La columna 2023/12/15 es de tipo float64
# La columna 2023/12/16 es de tipo float64
# La columna 2023/12/17 es de tipo float64
# La columna 2023/12/18 es de tipo float64
# La columna 2023/12/19 es de tipo float64
# La columna 2023/12/20 es de tipo float64
# La columna 2023/12/21 es de tipo float64
# La columna 2023/12/22 es de tipo float64
# La columna 2023/12/23 es de tipo float64
# La columna 2023/12/24 es de tipo float64
# La columna 2023/12/26 es de tipo float64
# La columna 2023/12/27 es de tipo float64
# La columna 2023/12/28 es de tipo float64
# La columna 2023/12/30 es de tipo float64
# La columna 2024/01/02 es de tipo float64
# La columna 2024/01/03 es de tipo float64
# La columna 2024/01/04 es de tipo float64
# La columna 2024/01/05 es de tipo float64
# La columna 2024/01/06 es de tipo float64
# La columna 2024/01/13 es de tipo float64
# La columna 2024/01/19 es de tipo float64
# La columna 2024/01/25 es de tipo float64
# La columna 2024/01/26 es de tipo float64
# La columna 2024/01/27 es de tipo float64
# La columna 2024/01/29 es de tipo float64
# La columna 2024/01/30 es de tipo float64
# La columna 2024/02/01 es de tipo float64
# La columna 2024/02/02 es de tipo float64
# La columna 2024/02/03 es de tipo float64
# La columna 2024/02/05 es de tipo float64
# La columna 2024/02/06 es de tipo float64
# La columna 2024/02/07 es de tipo float64
# La columna 2024/02/09 es de tipo float64
# La columna 2024/02/10 es de tipo float64
# La columna 2024/02/15 es de tipo float64
# La columna 2024/02/16 es de tipo float64
# La columna 2024/02/17 es de tipo float64
# La columna 2024/02/19 es de tipo float64
# La columna 2024/02/20 es de tipo float64
# La columna 2024/02/21 es de tipo float64
# La columna 2024/02/22 es de tipo object
# La columna 2024/02/23 es de tipo float64
# La columna 2024/02/24 es de tipo float64
# La columna 2024/02/26 es de tipo float64
# La columna 2024/02/29 es de tipo float64
# La columna 2024/03/01 es de tipo float64
# La columna 2024/03/02 es de tipo float64
# La columna 2024/03/04 es de tipo float64
# La columna 2024/03/06 es de tipo float64
# La columna 2024/03/07 es de tipo float64
# La columna 2024/03/08 es de tipo float64
# La columna 2024/03/09 es de tipo float64
# La columna 2024/03/10 es de tipo float64
# La columna 2024/03/11 es de tipo float64
# La columna 2024/03/13 es de tipo float64
# La columna 2024/03/14 es de tipo float64
# La columna 2024/03/15 es de tipo float64
# La columna 2024/03/16 es de tipo float64
# La columna 2024/03/19 es de tipo float64
# La columna 2024/03/20 es de tipo float64
# La columna 2024/03/21 es de tipo float64
# La columna 2024/03/24 es de tipo float64
# La columna 2024/03/25 es de tipo float64
# La columna 2024/03/26 es de tipo float64
# La columna 2024/03/27 es de tipo float64
# La columna 2024/03/28 es de tipo float64
# La columna 2024/03/30 es de tipo float64
# La columna 2024/03/31 es de tipo float64
# La columna 2024/04/02 es de tipo float64
# La columna 2024/04/04 es de tipo float64
# La columna 2024/04/05 es de tipo float64
# La columna 2024/04/06 es de tipo float64
# La columna 2024/04/07 es de tipo float64
# La columna 2024/04/08 es de tipo float64
# La columna 2024/04/10 es de tipo float64
# La columna 2024/04/11 es de tipo float64
# La columna 2024/04/12 es de tipo float64
# La columna 2024/04/13 es de tipo float64
# La columna 2024/04/14 es de tipo float64
# La columna 2024/04/15 es de tipo float64
# La columna 2024/04/16 es de tipo float64
# La columna 2024/04/17 es de tipo float64
# La columna 2024/04/19 es de tipo float64
# La columna 2024/04/20 es de tipo float64
# La columna 2024/04/21 es de tipo float64
# La columna 2024/04/23 es de tipo float64
# La columna 2024/04/27 es de tipo float64
# La columna 2024/04/28 es de tipo float64
# La columna 2024/04/29 es de tipo float64
# La columna 2024/04/30 es de tipo float64
# La columna 2024/05/01 es de tipo float64
# La columna 2024/05/03 es de tipo float64
# La columna 2024/05/04 es de tipo float64
# La columna 2024/05/05 es de tipo float64
# La columna 2024/05/07 es de tipo float64
# La columna 2024/05/09 es de tipo float64
# La columna 2024/05/10 es de tipo float64
# La columna 2024/05/11 es de tipo float64
# La columna 2024/05/13 es de tipo float64
# La columna 2024/05/14 es de tipo float64
# La columna 2024/05/16 es de tipo float64
# La columna 2024/05/17 es de tipo float64
# La columna 2024/05/19 es de tipo float64
# La columna 2024/05/20 es de tipo float64
# La columna 2024/05/22 es de tipo float64
# La columna 2024/05/23 es de tipo float64
# La columna 2024/05/24 es de tipo float64
# La columna 2024/05/25 es de tipo float64
# La columna 2024/05/28 es de tipo float64
# La columna 2024/05/30 es de tipo float64
# La columna 2024/06/01 es de tipo float64
# La columna 2024/06/03 es de tipo float64
# La columna 2024/06/05 es de tipo float64
# La columna 2024/06/06 es de tipo float64
# La columna 2024/06/08 es de tipo float64
# La columna 2024/06/10 es de tipo float64
# La columna 2024/06/11 es de tipo float64
# La columna 2024/06/13 es de tipo float64
# La columna 2024/06/14 es de tipo float64
# La columna 2024/06/15 es de tipo float64
# La columna 2024/06/17 es de tipo float64
# La columna 2024/06/18 es de tipo float64
# La columna 2024/06/20 es de tipo float64
# La columna 2024/06/21 es de tipo float64
# La columna 2024/06/24 es de tipo float64
# La columna 2024/06/25 es de tipo float64
# La columna 2024/06/26 es de tipo float64
# La columna 2024/06/27 es de tipo float64
# La columna 2024/06/28 es de tipo float64
# La columna 2024/06/29 es de tipo float64
# La columna 2024/07/01 es de tipo float64
# La columna 2024/07/02 es de tipo float64
# La columna 2024/07/03 es de tipo float64
# La columna 2024/07/04 es de tipo float64
# La columna 2024/07/05 es de tipo float64
# La columna 2024/07/07 es de tipo float64
# La columna 2024/07/08 es de tipo float64
# La columna 2024/07/10 es de tipo float64
# La columna 2024/07/11 es de tipo float64
# La columna 2024/07/12 es de tipo float64
# La columna 2024/07/13 es de tipo float64
# La columna 2024/07/14 es de tipo float64
# La columna 2024/07/16 es de tipo float64
# La columna 2024/07/18 es de tipo float64
# La columna 2024/07/20 es de tipo float64
# La columna source es de tipo object
# La columna 2023/05/08 es de tipo float64
# La columna 2023/06/28 es de tipo float64
# La columna 2023/07/11 es de tipo float64
# La columna 2023/07/27 es de tipo float64
# La columna 2023/08/30 es de tipo float64
# La columna 2023/10/07 es de tipo float64
# La columna 2023/10/17 es de tipo float64
# La columna 2023/10/25 es de tipo float64
# La columna 2023/11/14 es de tipo float64
# La columna 2023/12/03 es de tipo float64
# La columna 2024/01/24 es de tipo float64
# La columna 2023/06/26 es de tipo float64
# La columna 2023/08/01 es de tipo float64
# La columna 2023/08/24 es de tipo float64
# La columna 2023/12/07 es de tipo float64
# La columna 2024/01/12 es de tipo float64
# La columna 2024/03/18 es de tipo float64
# La columna 2024/03/23 es de tipo float64
# La columna 2024/04/09 es de tipo float64
# La columna 2024/05/18 es de tipo float64
# La columna 2024/05/31 es de tipo float64
# La columna 2023/03/27 es de tipo float64
# La columna 2023/05/13 es de tipo float64
# La columna 2023/05/22 es de tipo float64
# La columna 2023/06/01 es de tipo float64
# La columna 2023/06/12 es de tipo float64
# La columna 2023/06/04 es de tipo float64
# La columna 2023/09/26 es de tipo float64
# La columna 2023/09/28 es de tipo float64
# La columna 2023/09/22 es de tipo float64
# La columna 2023/11/07 es de tipo float64
# La columna 2023/11/21 es de tipo float64
# La columna 2024/01/16 es de tipo float64
# La columna 2024/01/17 es de tipo float64
# La columna 2024/01/20 es de tipo float64
# La columna 2024/03/12 es de tipo float64
# La columna 2024/03/22 es de tipo float64
# La columna 2024/05/08 es de tipo float64
# La columna 2023/12/01 es de tipo float64
# La columna 2024/01/18 es de tipo float64
# La columna 2024/01/31 es de tipo float64
# La columna 2024/06/09 es de tipo float64
# La columna 2024/07/15 es de tipo float64
# La columna 2023/04/17 es de tipo float64
# La columna 2023/11/26 es de tipo float64
# La columna 2024/01/23 es de tipo float64
# La columna 2024/07/06 es de tipo float64
# La columna 2024/07/17 es de tipo float64
# La columna 2024/04/03 es de tipo float64
# La columna 2024/07/21 es de tipo float64
# La columna 2023/04/28 es de tipo float64
# La columna 2023/06/15 es de tipo float64
# La columna 2023/08/14 es de tipo float64
# La columna 2023/08/22 es de tipo float64
# La columna 2023/01/19 es de tipo float64
# La columna 2023/01/31 es de tipo float64
# La columna 2024/02/28 es de tipo float64
# La columna 2023/06/06 es de tipo float64
# La columna 2023/07/01 es de tipo float64
# La columna 2023/07/26 es de tipo float64
# La columna 2024/01/10 es de tipo float64
# La columna 2024/04/25 es de tipo float64
# La columna 2024/05/27 es de tipo float64
# La columna 2024/05/29 es de tipo float64
# La columna 2024/06/02 es de tipo float64
# La columna 2024/06/22 es de tipo float64
# La columna 2024/07/19 es de tipo float64
# La columna 2023/05/24 es de tipo float64
# La columna 2023/06/14 es de tipo float64
# La columna 2023/07/04 es de tipo float64
# La columna 2023/07/13 es de tipo float64
# La columna 2023/07/28 es de tipo float64
# La columna 2023/08/09 es de tipo float64
# La columna 2023/08/10 es de tipo float64
# La columna 2023/08/29 es de tipo float64
# La columna 2023/09/05 es de tipo float64
# La columna 2023/11/04 es de tipo float64
# La columna 2024/01/11 es de tipo float64
# La columna 2024/04/18 es de tipo float64
# La columna 2024/04/24 es de tipo float64
# La columna 2024/05/06 es de tipo float64
# La columna 2024/05/21 es de tipo float64
# La columna 2024/05/26 es de tipo float64
# La columna 2024/06/04 es de tipo float64
# La columna 2024/06/12 es de tipo float64
# La columna 2023/07/22 es de tipo float64
# La columna 2023/09/30 es de tipo float64
# La columna 2024/01/22 es de tipo float64
# La columna 2024/03/05 es de tipo float64
# La columna 2023/03/29 es de tipo float64
# La columna 2023/07/29 es de tipo float64
# La columna 2023/01/25 es de tipo float64
# La columna 2023/06/07 es de tipo float64
# La columna 2023/08/15 es de tipo float64
# La columna 2024/01/15 es de tipo float64
# La columna 2024/04/26 es de tipo float64
# La columna 2023/11/12 es de tipo float64

# %%
# D. Melt: De formato wide a formato long
# Especificar las columnas que no deben ser melted
id_vars = ['COD', 'NUM', 'source']

# Realizar el melt del dataframe
all_melted = pd.melt(all, id_vars=id_vars, var_name='fecha_venta', value_name='count_items')
all_melted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 449280 entries, 0 to 449279
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   COD          449280 non-null  object
#  1   NUM          448864 non-null  float64
#  2   source       449280 non-null  object
#  3   fecha_venta  449280 non-null  object
#  4   count_items  1969 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 17.1+ MB

# %%
# E. Eliminar las filas con valores perdidos en la columna 'count_items'
# Esto corresponde a items que no tienen ingresos registrados
all_melted.dropna(subset=['count_items'], inplace=True)
all_melted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1969 entries, 104 to 449269
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   COD          1969 non-null   object
#  1   NUM          1969 non-null   float64
#  2   source       1969 non-null   object
#  3   fecha_venta  1969 non-null   object
#  4   count_items  1969 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 92.3+ KB

# %%
# F. Catch values with count_items == 0 and clean in file
print("Count items with values = 0")
print(all_melted[all_melted.count_items<=0][['COD', 'NUM', 'DET','source', 'fecha_venta', 'count_items']])

# G. Fecha venta validaciónd del largo
print("\n Lenght of fecha_ingreso")
print(all_melted.fecha_venta.str.len().value_counts(dropna=False))
# Out:
# Count items with values = 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 # F. Catch values with count_items == 0 and clean in file
#       2 print("Count items with values = 0")
# ----> 3 print(all_melted[all_melted.count_items<=0][['COD', 'NUM', 'DET','source', 'fecha_venta', 'count_items']])
#       5 # G. Fecha venta validaciónd del largo
#       6 print("\n Lenght of fecha_ingreso")
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/arraylike.py:52, in OpsMixin.__le__(self, other)
#      50 @unpack_zerodim_and_defer("__le__")
#      51 def __le__(self, other):
# ---> 52     return self._cmp_method(other, operator.le)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6119 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6121 return self._construct_result(res_values, name=res_name)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:344, in comparison_op(left, right, op)
#     341     return invalid_comparison(lvalues, rvalues, op)
#     343 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     346 else:
#     347     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:129, in comp_method_OBJECT_ARRAY(op, x, y)
#     127     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     128 else:
# --> 129     result = libops.scalar_compare(x.ravel(), y, op)
#     130 return result.reshape(x.shape)
#
# File ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '<=' not supported between instances of 'str' and 'int'

# %%
# H. Ajustar los data types
# Count items to int64
all_melted["count_items"] = all_melted.count_items.astype("Int64")

# fecha_venta to datetime- Format "dd/mm/yy"
all_melted["fecha_venta"] = pd.to_datetime(all_melted.fecha_venta, errors='raise')  

all_melted.info()

# %%
# I. Preview del dataset
all_melted.head()

# %% [markdown]
# # Save file

# %%
# 4. Save dataframe as Excel
all_melted.to_excel("data/clean_files/ventas_plata_melted.xlsx", index=False)
